# %% [markdown]
# # EV-Market segmentation(Pollution data)

# %% [markdown]
# #### Start-up EV(electric vehicles") sales in india we need to know the conditions whether its is Tempature,Price,Customers-Behaviour & present electric vehicle sales in india

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import warnings
import os

# %% [markdown]
# #### Now we look at the pollution data in india as per the city wise so we can estimate the ev sales which area is required more

# %%
pollution_data = pd.read_excel("C:\\Users\\Nandhavena Navignan\\Downloads\\Project\\pollution_data.xlsx")

# %%
pollution_data.head()
# Out:
#    city_name  AQI value  pollution level
# 0   Agartala         85   Satisfactory
# 1       Agra         78   Satisfactory
# 2  Ahmedabad         84   Satisfactory
# 3      Ajmer         68   Satisfactory
# 4      Alwar         69   Satisfactory

# %%
pollution_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city_name        196 non-null    object
#  1   AQI value        196 non-null    int64
#  2   pollution level  196 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.7+ KB

# %%
pollution_data.isnull().sum()
# Out:
# city_name          0
# AQI value          0
# pollution level    0
# dtype: int64

# %%
pollution_data.columns
# Out:
# Index(['city_name', 'AQI value', 'pollution level'], dtype='object')

# %%
pollution_data = pollution_data.rename(columns={' City Name ':'city_name',' AQI Value ':'AQI_value',' Pollution Level ':'pollution_level'})

# %%
pollution_data.columns
# Out:
# Index(['city_name', 'AQI value', 'pollution level'], dtype='object')

# %%
pollution_data
# Out:
#          city_name  AQI value  pollution level
# 0         Agartala         85   Satisfactory
# 1             Agra         78   Satisfactory
# 2        Ahmedabad         84   Satisfactory
# 3            Ajmer         68   Satisfactory
# 4            Alwar         69   Satisfactory
# ..             ...        ...              ...
# 191     Vijayawada         42           Good
# 192  Visakhapatnam         96   Satisfactory
# 193      Vrindavan        147       Moderate
# 194         Yadgir         67   Satisfactory
# 195    Yamunanagar        191       Moderate
#
# [196 rows x 3 columns]

# %%
sns.displot(data=pollution_data["pollution level"])

# %% [markdown]
# #### As per the Air quality index(AQI)
# #### 0-50 ------->GOOD
# #### 50-100 -------> Satisfactory
# #### 101-200 ------->Moderate
# #### 201-300 ------->poor
# ####  >300 ------->severe

# %%
plt.figure(figsize=(10,30))
sns.barplot('AQI value','city_name',data=pollution_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AQI value', ylabel='city_name'>
